# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
df = pd.read_csv('C:\\Users\\mansi\\OneDrive\\Desktop\\college\\sem-3\\DSAA\\dataset\\sale\\sale103.csv') 
df.head(5) # head command show the table data
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       45.70         6   3.8200  343.6700   3/8/2019
# 2      Home and lifestyle       78.90         7  16.2155  545.5000   3/3/2019
# 3       Health and beauty       54.67         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#using pandas library

# %%
#by using pandas library we can able see all correlation between columns

# %%
df.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.078261  0.648250  0.651581  0.648250
# Quantity                   0.078261  1.000000  0.729450  0.736393  0.729450
# Tax 5%                     0.648250  0.729450  1.000000  0.991249  1.000000
# Total                      0.651581  0.736393  0.991249  1.000000  0.991249
# cogs                       0.648250  0.729450  1.000000  0.991249  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.648250  0.729450  1.000000  0.991249  1.000000
# Rating                     0.067647  0.103581  0.076602  0.096506  0.076602
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.648250  0.067647
# Quantity                                     NaN      0.729450  0.103581
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# correlation using NUMPY library

# %%
#corrlatio itself is always 1 and what is correlation between Unit price and total is 6.51

# %%
np.corrcoef(df['Unit price'],df['Total'])
# Out:
# array([[1.        , 0.65158059],
#        [0.65158059, 1.        ]])

# %%
st.pearsonr(df['Unit price'],df['Total'])
# Out:
# (0.651580585747634, 2.804209057791542e-13)

# %%
sns.scatterplot(df['Unit price'],df['Total'])  //value0.651 showing moderate positve correlation
# Out:
# C:\Users\mansi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Unit price', ylabel='Total'>

# %%
#by looking out below plot we can state what kind of correlation between them

# %%
sns.pairplot(df)

# %%
#speatmanr correlation type

# %%
from scipy.stats import spearmanr

# %%
spearmanr(df['Unit price'],df['Total'])
# Out:
# SpearmanrResult(correlation=0.6446070928332563, pvalue=6.03336233848566e-13)

# %%
st.pearsonr(df['Unit price'],df['Total'])
# Out:
# (0.651580585747634, 2.804209057791542e-13)

# %%
#ANOVA (anlysis of variances in statistics with data science with python)

# %%
df.describe()
# Out:
#        Unit price   Quantity     Tax 5%       Total        cogs  \
# count   99.000000  99.000000  99.000000   99.000000   99.000000
# mean    59.254040   5.828283  17.367157  369.441848  347.343131
# std     26.646446   2.910363  12.034528  251.701322  240.690555
# min     12.450000   1.000000   0.771500   16.201500   15.430000
# 25%     38.280000   3.000000   7.485500  161.626500  149.710000
# 50%     60.880000   6.000000  16.072000  343.670000  321.440000
# 75%     83.420000   8.000000  25.826000  547.235750  516.520000
# max     99.420000  10.000000  44.740000  939.540000  894.800000
#
#        gross margin percentage  gross income     Rating
# count             9.900000e+01     99.000000  99.000000
# mean              4.761905e+00     17.367157   6.887879
# std               1.249778e-14     12.034528   1.695629
# min               4.761905e+00      0.771500   4.000000
# 25%               4.761905e+00      7.485500   5.650000
# ...

# %%
import scipy.stats as stats
import numpy as np
import statsmodels.api as sm

# %%
ratings=ratings_df.loc[(ratings_df['Unit price']<= 40),'product_price']='product price upto 40'
ratings=ratings_df.loc[(ratings_df['Unit price']>40)&(ratings_df['Unit price']>70),'product_price']='product price between between 41 to70'
ratings=ratings_df.loc[(ratings_df['Unit price'] >=71),'product_price']='product price betwwen 71 to 100 '
